# %%
import json
import os
import pandas as pd

# %%
root = '/Users/adelinechin/data'
f = open(os.path.join(root, 'ctg-studies.json'))
data = json.load(f)
f.close()

with open('subject.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
json_df = pd.read_json('subject.json')

# %%
# Extract nct id and conditions
json_df = json_df[['protocolSection']]
json_df['nctID'] = json_df['protocolSection'].apply(lambda x: x['identificationModule']['nctId'])
json_df['conditions'] = json_df['protocolSection'].apply(lambda x: x['conditionsModule']['conditions'])

# %%
# Make condition list into string to be able to search for substrings
def flatten_list(conditions):
  cond_str = ''
  for i, item in enumerate(conditions):
    if i == len(conditions)-1:
      cond_str = cond_str + item
    else:
      cond_str = cond_str + item + ' '
  return cond_str

# %%
# Prep df for category assignment
json_df['conditions'] = json_df['conditions'].apply(lambda x: flatten_list(x))
conditions_df = json_df.drop(columns=['protocolSection'])
conditions_df['conditions'] = conditions_df['conditions'].str.lower()

# %%
def conditions_map(condition):
    # lung
    if 'nsclc' in condition:
        return 'nsclc'
    if 'non-small cell lung' in condition:
        return 'nsclc'
    if 'non small cell lung' in condition:
        return 'nsclc'
    if 'sclc' in condition:
        return 'sclc'
    if 'small cell lung' in condition:
        return 'sclc'
    if 'lung' in condition:
        return 'lung'
    if 'malignant mesothelioma' in condition:
        return 'malignant mesothelioma'
    
    # head and neck
    if 'oral' in condition:
        return 'oral cavity and pharynx'
    if 'pharynx' in condition:
        return 'oral cavity and pharynx'
    if 'lip' in condition:
        return 'lip'
    if 'tongue' in condition:
        return 'tongue'
    if 'laryngeal' in condition:
        return 'laryngeal'
    if 'thyroid' in condition:
        return 'thyroid'
    if 'head and neck' in condition:
        return 'head and neck'
    
    # reproductive
    if 'cervical' in condition:
        return 'cervical'
    if 'cervix' in condition:
        return 'cervix'
    if 'endometrial' in condition:
        return 'endometrial'
    if 'endome' in condition:
        return 'endometrial'
    if 'invasive epithelial ovarian' in condition:
        return 'invasive epithelial ovarian'
    if 'ovarian stromal' in condition:
        return 'ovarian stromal'
    if 'germ cell tumor of ovary' in condition:
        return 'germ cell tumors of ovary'
    if 'germ cell tumors of ovary' in condition:
        return 'germ cell tumors of ovary'
    if 'fallopian tube' in condition:
        return 'fallopian tube'
    if 'ovarian' in condition:
        return 'ovarian'
    if 'ovary' in condition:
        return 'ovary'
    if 'anal' in condition:
        return 'anal'
    if 'rectum' in condition:
        return 'anal'
    if 'breast' in condition:
        return 'breast'
    if 'penile' in condition:
        return 'penile'
    if 'prostate' in condition:
        return 'prostate'
    if 'testicular' in condition:
        return 'testicular'
    if 'testicles' in condition:
        return 'testicular'
    if 'testes' in condition:
        return 'testicular'
    if 'vagina' in condition:
        return 'vaginal'
    if 'vulva' in condition:
        return 'vulvar'
    if 'leiomyosarcoma' in condition:
        return 'leiomyosarcoma'
    
    # digestive
    if 'intraheptic bile duct' in condition:
        return 'intraheptic bile duct'
    if 'extraheptic bile duct' in condition:
        return 'extraheptic bile duct'
    if 'bile duct' in condition:
        return 'bile duct'
    if 'colorectal' in condition:
        return 'colorectal'
    if 'colon' in condition:
        return 'colorectal'
    if 'esophagus' in condition:
        return 'esophagus'
    if 'esophageal' in condition:
        return 'esophagus'
    if 'gallbladder' in condition:
        return 'gallbladder'
    if 'gist' in condition:
        return 'gist'
    if 'gi' in condition:
        return 'gist'
    if 'gastrointestinal' in condition:
        return 'gist'
    if 'liver' in condition:
        return 'liver'
    if 'pancreatic' in condition:
        return 'pancreatic'
    if 'pancreas' in condition:
        return 'pancreatic'
    if 'small intestine' in condition:
        return 'small intestine'
    if 'stomach' in condition:
        return 'stomach'
    if 'gastric' in condition:
        return 'stomach'
    
    # urinary
    if 'bladder' in condition:
        return 'bladder'
    if 'kidney' in condition:
        return 'kidney'
    
    #

# %%
def conditions_map(condition):
  # squamous cell (carcinoma)
  if 'cell lung' in condition:
    return 'squamous cell'
  if 'head and neck' in condition:
    return 'squamous cell'
  if 'squamous cell' in condition:
    return 'squamous cell'
  if 'small cell' in condition:
    return 'squamous cell'
  if 'lung' in condition:
    return 'squamous cell'
  if 'keratosis' in condition:
    return 'squamous cell'
  if 'squamous' in condition:
    return 'squamous cell'
  if 'pelvic' in condition:
    return 'squamous cell'
  if 'uterine' in condition:
    return 'squamous cell'
  if 'ovarian' in condition:
    return 'squamous cell'
  if 'ovary' in condition:
    return 'squamous cell'
  if 'nsclc' in condition:
    return 'squamous cell'
  if 'oral' in condition:
    return 'squamous cell'

  # myeloma (blood)
  if 'myeloma' in condition:
    return 'myeloma'

  # sarcoma (bone/soft tissue)
  if 'sarcoma' in condition:
    return 'sarcoma'
  if 'gastrointestinal' in condition:
    return 'sarcoma'
  if 'bone' in condition:
    return 'sarcoma'

  # lymphoma (lymph system)
  if 'lymphoma' in condition:
    return 'lymphoma'
  if 'lymphoid' in condition:
    return 'lymphoma'
  if 'lymph' in condition:
    return 'lymphoma'

  # brain
  if 'brain cancer' in condition:
    return 'brain'
  if 'brain' in condition:
    return 'brain'
  if 'glioblastoma' in condition:
    return 'brain'
  if 'glioma' in condition:
    return 'brain'

  # melanoma (skin)
  if 'melanoma' in condition:
    return 'melanoma'
  if 'skin' in condition:
    return 'melanoma'

  # adenocarcinoma (carcinoma)
  if 'adenocarcinoma' in condition:
    return 'adeno'
  if 'prostate cancer' in condition:
    return 'adeno'
  if 'rectal' in condition:
    return 'adeno'
  if 'kidney' in condition:
    return 'adeno'
  if 'renal' in condition:
    return 'adeno'
  if 'gastric' in condition:
    return 'adeno'
  if 'gi' in condition:
    return 'adeno'
  if 'digestive' in condition:
    return 'adeno'
  if 'esophageal' in condition:
    return 'adeno'
  if 'cervix' in condition:
    return 'adeno'
  if 'cervical' in condition:
    return 'adeno'
  if 'liver' in condition:
    return 'adeno'
  if 'hepatic' in condition:
    return 'adeno'
  if 'hepatocellular' in condition:
    return 'adeno'
  if 'thyroid' in condition:
    return 'adeno'
  if 'abdomin' in condition:
    return 'adeno'

  # ductal (adenocarcinoma)
  if 'breast' in condition:
    return 'ductal'
  if 'pancreatic' in condition:
    return 'ductal'
  if 'pancreas' in condition:
    return 'ductal'

  # leukemia (blood)
  if 'leukemia' in condition:
    return 'leukemia'
  if 'hematopoietic' in condition:
    return 'leukemia'
  if 'myelofibrosis' in condition:
    return 'leukemia'

  # pediatric
  if 'blastoma' in condition:
    return 'pediatric'
  if 'pediatric' in condition:
    return 'pediatric'
  if 'child' in condition:
    return 'pediatric'

  if 'bladder' in condition:
    return 'transitional cell'

  if 'neoplasm' in condition:
    return 'neoplasm'

  if 'pain' in condition:
    return 'pain'
  elif 'carcinoma' in condition:
    return 'carcinoma'
  return 'other'

# %%
conditions_5yr_survival_map_df = pd.read_csv('survival_dict.csv')
conditions_5yr_survival_map_df = conditions_5yr_survival_map_df.set_index('type')
conditions_5yr_survival_map = conditions_5yr_survival_map_df.to_dict('index')

# %%
conditions_5yr_survival_map
# Out:
# {'nsclc': {'5yr_survival': 0.28},
#  'sclc': {'5yr_survival': 0.07},
#  'lung': {'5yr_survival': 0.175},
#  'oral cavity and pharynx': {'5yr_survival': 0.68},
#  'lip': {'5yr_survival': 0.914},
#  'tongue': {'5yr_survival': 0.688},
#  'laryngeal': {'5yr_survival': 0.61},
#  'thyroid': {'5yr_survival': 0.984},
#  'head and neck': {'5yr_survival': 0.7752},
#  'cervical': {'5yr_survival': 0.67},
#  'endometrial': {'5yr_survival': 0.81},
#  'invasive epithelial ovarian': {'5yr_survival': 0.5},
#  'ovarian stromal': {'5yr_survival': 0.89},
#  'germ cell tumors of ovary': {'5yr_survival': 0.92},
#  'fallopian tube': {'5yr_survival': 0.55},
#  'ovarian': {'5yr_survival': 0.715},
#  'anal': {'5yr_survival': 0.7},
#  'intraheptic bile duct': {'5yr_survival': 0.09},
#  'extraheptic bile duct': {'5yr_survival': 0.11},
#  'bile duct': {'5yr_survival': 0.1},
#  'colorectal': {'5yr_survival': 0.63},
#  'esophagus ': {'5yr_survival': 0.22},
#  'gallbladder': {'5yr_survival': 0.2},
#  'gist': {'5yr_survival': 0.82},
#  'liver': {'5yr_survival': 0.22},
#  'pancreatic': {'5yr_survival': 0.13},
#  'small intestine': {'5yr_survival': 0.69},
#  'stomach': {'5yr_survival': 0.36},
#  'bladder': {'5yr_survival': 0.78},
#  'kidney': {'5yr_survival': 0.78},
#  'malignant mesothelioma': {'5yr_survival': 0.12},
#  'breast': {'5yr_survival': 0.91},
#  'penile': {'5yr_survival': 0.65},
#  'prostate': {'5yr_survival': 0.97},
#  'testicular': {'5yr_survival': 0.95},
#  'vaginal': {'5yr_survival': 0.51},
#  'leiomyosarcoma': {'5yr_survival': 0.38},
#  'undifferentiated sarcoma': {'5yr_survival': 0.43},
#  'endometrial stromal sarcoma': {'5yr_survival': 0.96},
#  'uterine sarcoma': {'5yr_survival': 0.57},
#  'vulvar': {'5yr_survival': 0.71},
#  'adrenal': {'5yr_survival': 0.5},
#  'melanoma': {'5yr_survival': 0.94},
#  'eye': {'5yr_survival': 0.81},
#  'soft tissue sarcoma': {'5yr_survival': 0.65},
#  'osteosarcoma': {'5yr_survival': 0.59},
#  'chondrosarcoma': {'5yr_survival': 0.79},
#  'chordoma': {'5yr_survival': 0.84},
#  'giant cell tumor of bone': {'5yr_survival': 0.78},
#  'bone ': {'5yr_survival': 0.8033333333},
#  'low-grade astrocytoma': {'5yr_survival': 0.48},
#  'anaplastic astrocytoma': {'5yr_survival': 0.34},
#  'glioblastoma': {'5yr_survival': 0.12},
#  'oligodendroglioma': {'5yr_survival': 0.8},
#  'anaplastic oligodendroglioma': {'5yr_survival': 0.63},
#  'ependymoma': {'5yr_survival': 0.9},
#  'meningioma': {'5yr_survival': 0.79},
#  'brain': {'5yr_survival': 0.58},
#  'myeloma': {'5yr_survival': 0.58},
#  'hodgkin lymphoma': {'5yr_survival': 0.89},
#  'non-hodgkin lymphoma': {'5yr_survival': 0.78},
#  'lymphoma': {'5yr_survival': 0.835},
#  'leukemia': {'5yr_survival': 0.67},
#  'aml': {'5yr_survival': 0.295},
#  'all': {'5yr_survival': 0.681},
#  'other': {'5yr_survival': 0.708},
#  'pain': {'5yr_survival': nan},
#  'pediatric': {'5yr_survival': 0.6949166667},
#  'peds pilocytic astrocytoma': {'5yr_survival': 0.95},
#  'peds diffuse astrocytoma': {'5yr_survival': 0.825},
#  'peds anaplastic astrocytoma': {'5yr_survival': 0.25},
#  'peds glioblastoma': {'5yr_survival': 0.2},
#  'peds oligodendroglioma': {'5yr_survival': 0.9},
#  'peds ependymoma': {'5yr_survival': 0.75},
#  'peds embryonal tumors': {'5yr_survival': 0.625},
#  'peds brain': {'5yr_survival': 0.6428571429},
#  'peds all': {'5yr_survival': 0.9},
#  'peds aml': {'5yr_survival': 0.675},
#  'peds jmml': {'5yr_survival': 0.5},
#  'peds cml': {'5yr_survival': 0.7},
#  'peds leukemia': {'5yr_survival': 0.69375}}
